# %% [markdown]
# <br><br><center><h1 style="font-size:4em;color:#2467C0">New distributions(Assignment)</h1></center>
# <br>
# <table>
#     <col width="500">
#     <tr>
#     <p> The objective of this document is to stablish a solid understanding of the following types of distributions: Uniform, Bernoulli and Weibull </p>
#     </tr>
#     <tr>
#         <td><img src="https://miro.medium.com/max/962/1*DmPUIjvecL7KllOamoFSDw.png" align="middle" style="width:590px;height:340px;"/></td>
#     </tr>
#     <tr>
#         <td>Lenin Escobar  |  Statistical Foundations for Data Science  |  Monday, October 26, 2020</td>
#     </tr>
# </table>

# %%
# %config IPCompleter.greedy=True
# %load_ext memory_profiler
# %run Assignment_Distributions_helper.ipynb
# %run Assignment_Distributions_plot.ipynb
# Within IPython notebook, add multiple print capabilities
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
#%matplotlib notebook
# %matplotlib inline
import numpy as np
# Out:
# The memory_profiler extension is already loaded. To reload it, use:
#   %reload_ext memory_profiler

# %% [markdown]
# <h6 style="font-size:2em;color:#2467C0">Uniform Distribution</h6>

# %% [markdown]
# <p style="font-size:150%;color:blue;">Definition</p>
#
# A uniform distribution, also called a rectangular distribution, is a probability distribution that has constant probability.
#
# This distribution is defined by two parameters, a and b:
#
# a is the minimum.
#
# b is the maximum.
#
# The distribution is written as U(a,b)
#
# <p style="font-size:150%;color:blue;">Types</p>
#
# This distribution has two types:
#
# - <strong>Continuous </strong> uniform distribution (lines in the shape of a rectangle) with an infinite number of outcomes.
#
#     "A" is the location parameter (where the center of the graph is).
#
#     "B" is the scale parameter (stretches the graph out on the horizontal axis).
#
#     A graph of the PDF looks like this:
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/9/96/Uniform_Distribution_PDF_SVG.svg/500px-Uniform_Distribution_PDF_SVG.svg.png" align="middle" style="width:590px;height:340px;"/>
#
#     A graph of the CDF looks like this:
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/6/63/Uniform_cdf.svg/500px-Uniform_cdf.svg.png" align="middle" style="width:590px;height:340px;"/>
#
# - <strong>Discrete</strong> uniform distribution (dots in the shape of a rectangle) with a finite number of outcomes (equally likely to be observed; every one of n values has equal probability 1/n).
#
#      A graph of the PDF/PMF (where n = 5 where n = b − a + 1) looks like this:
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/1/1f/Uniform_discrete_pmf_svg.svg/650px-Uniform_discrete_pmf_svg.svg.png" align="middle" style="width:590px;height:340px;"/>
#
#     A graph of the CDF looks like this:
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/7/77/Dis_Uniform_distribution_CDF.svg/650px-Dis_Uniform_distribution_CDF.svg.png" align="middle" style="width:590px;height:340px;"/>
#
# <p style="font-size:150%;color:blue;">Uniform PDF</p>
#
# The probability density function (PDF) is:
# $\{\\ -\infty < a < b < \infty \\ f(x) = \frac{1}{(b-a)} for \ x ∈ \lbrack a,b \rbrack \\ 0 \ otherwise \\ \}$
#
# Note that the length of the base of the rectangle is $(b-a) $, while the length of the height of the rectangle is $\frac{1}{(b-a)} $. Therefore, as should be expected, the area $f(x)$ under  and between the endpoints $a$ and $b$ is 1. Additionally, $f(x) > 0 $  over the support $a < x < b$ . Therefore, $f(x)$  is a valid probability density function.
#
# <p style="font-size:150%;color:blue;">Uniform CDF</p>
#
# The cumulative distribution function of a uniform random variable x is:
#
# $\{\\ -\infty < a < b < \infty \\ 0\ for\ x < a \\ f(x) = \frac{x-a}{(b-a)} for \ x ∈ \lbrack a,b \rbrack \\ 1\ for\ x > b \\ \}$
#
# <p style="font-size:150%;color:blue;">Examples</p>

# %%
'''
fig = plt.figure()
fig.subplots_adjust(hspace=0.4, wspace=0.4)
ax = fig.add_subplot(2, 2, 1)
title = 'Real life example'
txt_place = 'right'
cal_kde_bw = False
ax_hist_xlabel = 'Uniform Dist'
ax_hist_ylabel = 'Frequency'
sns_boxplot_distplot_one_col_df(df['val'], title, txt_place, cal_kde_bw, ax_hist_xlabel, ax_hist_ylabel)
ax = fig.add_subplot(2, 2, 2)
title = 'Real life example'
txt_place = 'right'
cal_kde_bw = False
ax_hist_xlabel = 'Uniform Dist'
ax_hist_ylabel = 'Frequency'
sns_boxplot_distplot_one_col_df(df['val'], title, txt_place, cal_kde_bw, ax_hist_xlabel, ax_hist_ylabel)
ax = fig.add_subplot(2, 2, 3)
title = 'Real life example'
txt_place = 'right'
cal_kde_bw = False
ax_hist_xlabel = 'Uniform Dist'
ax_hist_ylabel = 'Frequency'
sns_boxplot_distplot_one_col_df(df['val'], title, txt_place, cal_kde_bw, ax_hist_xlabel, ax_hist_ylabel)
ax = fig.add_subplot(2, 2, 4)
title = 'Real life example'
txt_place = 'right'
cal_kde_bw = False
ax_hist_xlabel = 'Uniform Dist'
ax_hist_ylabel = 'Frequency'
sns_boxplot_distplot_one_col_df(df['val'], title, txt_place, cal_kde_bw, ax_hist_xlabel, ax_hist_ylabel)
'''
# Out:
# "\nfig = plt.figure()\nfig.subplots_adjust(hspace=0.4, wspace=0.4)\nax = fig.add_subplot(2, 2, 1)\ntitle = 'Real life example'\ntxt_place = 'right'\ncal_kde_bw = False\nax_hist_xlabel = 'Uniform Dist'\nax_hist_ylabel = 'Frequency'\nsns_boxplot_distplot_one_col_df(df['val'], title, txt_place, cal_kde_bw, ax_hist_xlabel, ax_hist_ylabel)\nax = fig.add_subplot(2, 2, 2)\ntitle = 'Real life example'\ntxt_place = 'right'\ncal_kde_bw = False\nax_hist_xlabel = 'Uniform Dist'\nax_hist_ylabel = 'Frequency'\nsns_boxplot_distplot_one_col_df(df['val'], title, txt_place, cal_kde_bw, ax_hist_xlabel, ax_hist_ylabel)\nax = fig.add_subplot(2, 2, 3)\ntitle = 'Real life example'\ntxt_place = 'right'\ncal_kde_bw = False\nax_hist_xlabel = 'Uniform Dist'\nax_hist_ylabel = 'Frequency'\nsns_boxplot_distplot_one_col_df(df['val'], title, txt_place, cal_kde_bw, ax_hist_xlabel, ax_hist_ylabel)\nax = fig.add_subplot(2, 2, 4)\ntitle = 'Real life example'\ntxt_place = 'right'\ncal_kde_bw = False\nax_hist_xlabel = 'Uniform Dist'\nax_hist_ylabel = 'Frequency'\nsns_boxplot_distplot_one_col_df(df['val'], title, txt_place, cal_kde_bw, ax_hist_xlabel, ax_hist_ylabel)\n"

# %%
_loc=50
_scale=100
_size=10000

uniform_dist_data = uniform_dist_rvs(_loc, _scale, _size)
df = df_From_ndarray(uniform_dist_data)
df = df.rename(columns={0: "val"})

title = 'Real life example with params: Loc->' + str(_loc) + ' Scale->' + str(_scale) + ' Size->' + str(_size)
txt_place = 'right'
cal_kde_bw = False
ax_hist_xlabel = 'Uniform Dist'
ax_hist_ylabel = 'Frequency'
sns_boxplot_distplot_one_col_df(df['val'], title, txt_place, cal_kde_bw, ax_hist_xlabel, ax_hist_ylabel)

# %%
_loc=70
_scale=100
_size=10000

uniform_dist_data = uniform_dist_rvs(_loc, _scale, _size)
df = df_From_ndarray(uniform_dist_data)
df = df.rename(columns={0: "val"})

title = 'Real life example with params: Loc->' + str(_loc) + ' Scale->' + str(_scale) + ' Size->' + str(_size)
txt_place = 'right'
cal_kde_bw = False
ax_hist_xlabel = 'Uniform Dist'
ax_hist_ylabel = 'Frequency'
sns_boxplot_distplot_one_col_df(df['val'], title, txt_place, cal_kde_bw, ax_hist_xlabel, ax_hist_ylabel)

# %% [markdown]
# <p style="font-size:150%;color:blue;">Real example statement</p>

# %% [markdown]
# A shuttle train at an airport completes a circuit between 2 terminals every 5 minutes. What is the probability that a passenger will wait more than 3 minutes for a shuttle train?

# %% [markdown]
# The random variable x = waiting time
# assumption:The waiting time is uniformly distributed between 0 and 5
#
# $\{ f(x) = \frac{1}{(5)} for \ x ∈  0 < x < 5 \}$
#
# $p(x>3) = \frac{5 -3}{5} = \ \frac{2}{5} = 0.4 $

# %%
_loc=3
_scale=5
_size=10000

uniform_dist_data = uniform_dist_rvs(_loc, _scale, _size)
df = df_From_ndarray(uniform_dist_data)
df = df.rename(columns={0: "val"})

title = 'Real life example with params: Loc->' + str(_loc) + ' Scale->' + str(_scale) + ' Size->' + str(_size)
txt_place = 'right'
cal_kde_bw = False
ax_hist_xlabel = 'Uniform Dist'
ax_hist_ylabel = 'Frequency'
sns_boxplot_distplot_one_col_df(df['val'], title, txt_place, cal_kde_bw, ax_hist_xlabel, ax_hist_ylabel)

# %%
# Plotting cdf
_loc=3
_scale=5
_title= "CDF"
plot_cdf_uniform_distribution(_loc, _scale, _title)

# %% [markdown]
# <h6 style="font-size:2em;color:#2467C0">Bernoulli Distribution</h6>

# %% [markdown]
# <p style="font-size:150%;color:blue;">Definition</p>
#
# Is the discrete probability distribution of a random variable which takes the value 1 with probability <strong>p</strong> and the value 0 with probability <strong>q=1-p</strong>. Less formally, it can be thought of as a model for the set of possible outcomes of any single experiment that asks a yes–no question. Such questions lead to outcomes that are boolean-valued: a single bit whose value is success/yes/true/one with probability <strong>p</strong> and failure/no/false/zero with probability <strong>q</strong>. It can be used to represent a (possibly biased) coin toss where 1 and 0 would represent "heads" and "tails" (or vice versa), respectively, and <strong>p</strong> would be the probability of the coin landing on heads or tails, respectively. In particular, unfair coins would have $\ p \neq \frac{1}{2}$
#
# The Bernoulli distribution is a special case of the binomial distribution where a single trial is conducted (so n would be 1 for such a binomial distribution). It is also a special case of the two-point distribution, for which the possible outcomes need not be 0 and 1.
#
# <p style="font-size:150%;color:blue;">Parameters</p>
#
# $ 0 \leq p \leq 1  \\ q = 1 - p \\ k ∈ \{ 0,1\} $
#
# <p style="font-size:150%;color:blue;">PDF</p>
#
# $\{ q = 1 -p \ if \ k = 0 \\ p \ if \ k = 1 \}$
#
# $ p^k ( 1 - p)^1-k $
#
# <p style="font-size:150%;color:blue;">CDF</p>
#
# $\{ 0 \ if \ k < 0 \\ 1 - p \ if \ 0 \le k <1 \\ 1 \ if \ k \ge 1 \}$

# %% [markdown]
# <p style="font-size:150%;color:blue;">Real example statement</p>

# %% [markdown]
# The last soccer football game a forward shooted at gold 10 times. 1 shot to the goal post, 8 wide fail to hit the target and 1 resulted in the goal score. What was the probability of goal shot failed?

# %% [markdown]
# The random variable n = number of shots
#
# $ p(n) = \frac{1}{10} = 0.1 $
#
# $q = 1 - \frac{1}{10} = \ \frac{9}{10} = 0.9 $

# %%
_p=0.1
_size=10000

bern_dist_data = bernoulli_dist_rsv(_p, _size)
df = df_From_ndarray(bern_dist_data)
df = df.rename(columns={0: "val"})

title = 'PDF - Real life example with params: Prob->' + str(_p) +' Size->' + str(_size)
txt_place = 'right'
cal_kde_bw = False
ax_hist_xlabel = 'Uniform Dist'
ax_hist_ylabel = 'Frequency'
sns_boxplot_distplot_one_col_df(df['val'], title, txt_place, cal_kde_bw, ax_hist_xlabel, ax_hist_ylabel)

# %%
x = [0,1]
prob = bernoulli.cdf(x, _p)
prob
# Out:
# array([0.9, 1. ])

# %%
_title = "CDF"
_df = df_From_ndarray(prob)
sns_scatterplot_one_col_df(_df, _title)

# %% [markdown]
# <h6 style="font-size:2em;color:#2467C0">Weibull distribution</h6>

# %% [markdown]
# <p style="font-size:150%;color:blue;">Definition</p>
#
# The Weibull distribution is a continuous probability distribution and one of the most widely used lifetime distributions in reliability engineering. It is a versatile distribution that can take on the characteristics of other types of distributions, based on the value of the shape parameter, γ. The Weibull can also fit a wide range of data from many other fields, including: biology, economics, engineering sciences, and hydrology.
#
# Although it’s extremely useful in most cases, the Weibull isn’t an appropriate model for every situation. For example, chemical reactions and corrosion failures are usually modeled with the lognormal distribution.
#
# <p style="font-size:150%;color:blue;">Characteristics</p>
#
# <ul>
#   <li>Another generalization of the exponential distribution (When γ = 1 then is equal to exponential distribution)</li>
#   <li>Popular in reliability and survival analysis</li>
#   <li>Positive scale parameter α</li>
#   <li>Positive shape parameter γ</li>
#   <li>When 3 &lt; γ &gt; 4, the pdf is nearly symetric </li>
#   <li>Closed-form CDF
#    $\{ f(x) = 0 \ if \ x \le  0 \\ 1 - e^{-(αx)^γ} \ if \ x > 0 \}$
#    </li>
# </ul>
#
# <p style="font-size:150%;color:blue;">Weibull Probability Density Function</p>
#
# <strong> The 3-Parameter Weibull </strong>
#
# The 3-parameter Weibull pdf is given by:
#
# <img src="https://www.statisticshowto.com/wp-content/uploads/2014/03/pdf-weibull-distribution.png" align="middle"/>
#
# and:
#
# <strong> γ </strong> is the shape parameter (also known as the Weibull slope or the threshold parameter).
#
# <strong> α </strong> is the scale parameter, also called the characteristic life parameter.
#
# <strong> μ </strong> is the location parameter, also called the waiting time parameter or sometimes the shift parameter or failure free life. Note: μ the time to failure, is not included in the two parameter version.
#
# When μ = 0 and α = 1, the formula for the pdf reduces to:
#
# <img src="https://www.statisticshowto.com/wp-content/uploads/2014/03/pdf-weibull-distribution-1.png" align="middle"/>
#
# which is the <strong> standard Weibull distribution </strong>.
#
# <strong>The 2-Parameter Weibull</strong>
#
# The formula is practically identical to the three parameter Weibull, except that μ isn’t included:
#
# <img src="https://www.statisticshowto.com/wp-content/uploads/2014/03/two-parameter-weibull-pdf.png" align="middle"/>
#
# The two parameter Weibull is often used in failure analysis, because no failure can happen before time zero. If you know μ, the time where the failure happens, you can subtract it from x (i.e. time t). Therefore, when you move from the two-parameter to the three-parameter version, all you have to do is replace each instance of x with (x – μ).
#
# <p style="font-size:150%;color:blue;">The Weibull Family</p>
#
# The Weibull distribution is a family of distributions that can take on many shapes, depending on what parameters you choose.

# %%
# %run Assignment_Distributions_plot.ipynb

# %%
plot_weibull_family()

# %% [markdown]
# <p style="font-size:150%;color:blue;">Real life Examples</p>

# %% [markdown]
# The lifetime X, measure in hrs, of a spring that is operated continuously has CDF
#
# $\{ \ 0 \ if \ x \le  0 \\ 1 - e^{-(αx)^γ} \ if \ x > 0 \}$
#
# Where α = 0.001 and γ = 2. Find
#     a- The probability that a new spring survives 30 h
#     b- The probability that a spring that has been operating without failure for 50h survives an additional 30 h

# %% [markdown]
# Answers:
#
#     a- p(x > 30) = 1 - p(x$ \le 30$) = 1 - f(30) = e -(0.001 30)2 = 0.9991
#
#     b- p(x>80| x >50) = p(x>80) / p(x>50) = 1 - f(80) / 1 - f(50) = e -(0.001 80)2 / e -(0.001 50)2 = 0.9961
